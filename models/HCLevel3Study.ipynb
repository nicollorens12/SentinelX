# %% [markdown]
# ## Data Analysis and Visualization of the Bigger Dataset
#
# As seen in the other two notebooks we had to oversample the threee miniority classes, resulting in poor performance on level 3 model.
#
# In this notebook we will try to get more real data instead of oversampling the minority classes.
#
# We've obtained the data as a parquet file from Kaggle [Complete CICIDS Dataset](https://www.kaggle.com/datasets/dhoogla/cicidscollection?resource=download)

# %%
#!pip install fastparquet
#%pip install xgboost

# %%
from fastparquet import ParquetFile
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet('Datasets/Complete/cic-collection.parquet')

# %%
data.describe()
# Out:
#        Flow Duration  Total Fwd Packets  Total Backward Packets  \
# count   9.167581e+06       9.167581e+06            9.167581e+06
# mean    1.590669e+07       4.079505e+01            9.505221e+00
# std     6.569715e+08       2.066283e+03            5.805652e+02
# min    -9.190110e+11       0.000000e+00            0.000000e+00
# 25%     1.160100e+04       2.000000e+00            1.000000e+00
# 50%     3.966860e+05       3.000000e+00            2.000000e+00
# 75%     5.562333e+06       7.000000e+00            5.000000e+00
# max     1.200000e+08       3.096290e+05            2.919220e+05
#
#        Fwd Packets Length Total  Bwd Packets Length Total  \
# count              9.167581e+06              9.167581e+06
# mean               2.063825e+03              1.001084e+04
# std                8.358580e+04              1.281297e+06
# min                0.000000e+00              0.000000e+00
# 25%                2.900000e+01              0.000000e+00
# 50%                9.700000e+01              2.320000e+02
# 75%                9.350000e+02              9.640000e+02
# max                1.443918e+08              6.554530e+08
#
#        Fwd Packet Length Max  Fwd Packet Length Mean  Fwd Packet Length Std  \
# count           9.167581e+06            9.167581e+06           9.167581e+06
# mean            2.946960e+02            8.127664e+01           1.043248e+02
# std             5.018536e+02            1.422410e+02           1.989876e+02
# min             0.000000e+00            0.000000e+00           0.000000e+00
# 25%             2.000000e+01            7.000000e+00           0.000000e+00
# 50%             5.500000e+01            4.400000e+01           1.154701e+01
# 75%             5.070000e+02            1.076667e+02           1.807106e+02
# max             6.444000e+04            1.652931e+04           1.840158e+04
#
#        Bwd Packet Length Max  Bwd Packet Length Mean  ...  \
# count           9.167581e+06            9.167581e+06  ...
# mean            6.070652e+02            2.002887e+02  ...
# std             1.180525e+03            3.792937e+02  ...
# min             0.000000e+00            0.000000e+00  ...
# 25%             0.000000e+00            0.000000e+00  ...
# 50%             1.520000e+02            1.080000e+02  ...
# 75%             9.640000e+02            2.163750e+02  ...
# max             6.516000e+04            3.387929e+04  ...
#
#        Fwd Act Data Packets  Fwd Seg Size Min   Active Mean    Active Std  \
# count          9.167581e+06      9.167581e+06  9.167581e+06  9.167581e+06
# mean           3.634311e+01     -1.071509e+06  1.167681e+05  5.520761e+04
# std            2.053093e+03      3.372568e+07  1.476691e+06  8.546709e+05
# min            0.000000e+00     -1.408238e+09  0.000000e+00  0.000000e+00
# 25%            0.000000e+00      2.000000e+01  0.000000e+00  0.000000e+00
# 50%            1.000000e+00      2.000000e+01  0.000000e+00  0.000000e+00
# 75%            4.000000e+00      2.000000e+01  0.000000e+00  0.000000e+00
# max            3.096280e+05      6.724045e+07  1.140000e+08  7.495335e+07
#
#          Active Max    Active Min     Idle Mean      Idle Std      Idle Max  \
# count  9.167581e+06  9.167581e+06  9.167581e+06  9.167581e+06  9.167581e+06
# mean   1.930339e+05  8.280822e+04  8.015305e+06  5.491758e+05  8.775097e+06
# std    1.981935e+06  1.272038e+06  3.503701e+08  2.251441e+08  8.321556e+08
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    1.140000e+08  1.140000e+08  3.955714e+11  2.622479e+11  9.797810e+11
#
#            Idle Min
# count  9.167581e+06
# mean   7.413580e+06
# std    8.463088e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    2.399340e+11
#
# [8 rows x 57 columns]

# %%
data['Label'].value_counts().plot(kind='bar', title='Distribución de ataques')
#print(data['Label'].value_counts())
print(data['Label'].str.contains('bruteforce', case=False).value_counts())
print(data['Label'].str.contains('portscan', case=False).value_counts())
print(data['Label'].str.contains('xss', case=False).value_counts())
# Out:
# Label
# False    9062317
# True      105264
# Name: count, dtype: int64
# Label
# False    9165326
# True        2255
# Name: count, dtype: int64
# Label
# False    9166705
# True         876
# Name: count, dtype: int64

# %%
data.columns = data.columns.str.strip()
data.rename(columns={'Label': 'AttackType'}, inplace=True)
data = data[data['AttackType'].str.contains('Webattack-Bruteforce|Webattack-XSS|Webattack-SQLi', case=False)]


data['AttackType'] = data['AttackType'].str.replace('Webattack-bruteforce', 'BruteForce', case=False)
data['AttackType'] = data['AttackType'].str.replace('Webattack-XSS', 'XSS', case=False)
data['AttackType'] = data['AttackType'].str.replace('Webattack-SQLi', 'SQLInjection', case=False)

print(data['AttackType'].value_counts())
# Out:
# AttackType
# BruteForce      2020
# XSS              876
# SQLInjection      99
# Name: count, dtype: int64

# %%
dataSmall = pd.read_csv('Datasets/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
dataSmall.columns = dataSmall.columns.str.strip()

dataSmall.rename(columns={'Label': 'AttackType'}, inplace=True)
dataSmall.replace([np.inf, -np.inf], np.nan, inplace=True)
nan_values = dataSmall.isna().sum().sum()

dataSmall.dropna(inplace=True)
dataSmall['AttackType'] = dataSmall['AttackType'].str.replace('�', '-')

dataSmall['AttackType'] = dataSmall['AttackType'].str.replace('Web Attack - Brute Force', 'BruteForce', case=False)
dataSmall['AttackType'] = dataSmall['AttackType'].str.replace('Web Attack - XSS', 'XSS', case=False)
dataSmall['AttackType'] = dataSmall['AttackType'].str.replace('Web Attack - Sql Injection', 'SQLInjection', case=False)

dataSmall = dataSmall[dataSmall['AttackType'] != 'BENIGN']

print(dataSmall['AttackType'].value_counts())
# Out:
# AttackType
# BruteForce      1507
# XSS              652
# SQLInjection      21
# Name: count, dtype: int64

# %%
# Check if dataSmall and data have the same columns
columns_data = set(data.columns)
columns_dataSmall = set(dataSmall.columns)

if columns_data == columns_dataSmall:
    print("dataSmall and data have the same columns.")
else:
    print("dataSmall and data do not have the same columns.")
    print("Columns in data but not in dataSmall:", columns_data - columns_dataSmall)
    print("Columns in dataSmall but not in data:", columns_dataSmall - columns_data)
    
    shared_columns = columns_data.intersection(columns_dataSmall)
    print(f"Number of columns they share: {len(shared_columns)}")

    with open('shared_columns1.txt', 'w') as f:
        for column in shared_columns:
            f.write(f"{column}\n")
# Out:
# dataSmall and data do not have the same columns.
# Columns in data but not in dataSmall: {'ClassLabel', 'Fwd Act Data Packets', 'Init Fwd Win Bytes', 'Bwd Packets Length Total', 'Init Bwd Win Bytes', 'Fwd Seg Size Min', 'Fwd Packets Length Total', 'Avg Packet Size', 'Packet Length Max'}
# Columns in dataSmall but not in data: {'Down/Up Ratio', 'Total Length of Bwd Packets', 'Fwd Avg Bulk Rate', 'Fwd URG Flags', 'FIN Flag Count', 'Bwd Avg Bytes/Bulk', 'ECE Flag Count', 'Average Packet Size', 'Total Length of Fwd Packets', 'Fwd Avg Bytes/Bulk', 'ACK Flag Count', 'RST Flag Count', 'min_seg_size_forward', 'act_data_pkt_fwd', 'Destination Port', 'Init_Win_bytes_forward', 'PSH Flag Count', 'Fwd Header Length.1', 'Bwd Avg Packets/Bulk', 'CWE Flag Count', 'Max Packet Length', 'Min Packet Length', 'Bwd Packet Length Min', 'Init_Win_bytes_backward', 'Bwd Avg Bulk Rate', 'Fwd Packet Length Min', 'Fwd Avg Packets/Bulk', 'Bwd PSH Flags', 'Bwd URG Flags'}
# Number of columns they share: 50

# %% [markdown]
# We have a considerable amount of atributes they share so the model can be trained on the combined data and then between Level 2 and Level 3 there should be a process to filter the data to the attributes that are shared between the two datasets.

# %%
# Remove columns that are not shared
shared_columns = list(shared_columns)
data = data[shared_columns]
dataSmall = dataSmall[shared_columns]

# Concatenate the dataframes
data_combined = pd.concat([data, dataSmall], ignore_index=True)
data_combined.shape

data_combined['AttackType'].value_counts().plot(kind='bar', title='Distribución de ataques')
print(data_combined['AttackType'].value_counts())
# Out:
# AttackType
# BruteForce      3527
# XSS             1528
# SQLInjection     120
# Name: count, dtype: int64

# %% [markdown]
# We then now need to see if performance improves with the new data.

# %%
data_combined.columns = data_combined.columns.str.strip()
data.columns = data.columns.str.strip()

# %% [markdown]
# ## New Level 3 Test

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from imblearn.over_sampling import SMOTE
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
X = data.drop(columns=['AttackType'])
y = data['AttackType']

# %%
target_classes = {
    "BruteForce": 50000,
    "XSS": 50000,
    "SQLInjection": 50000
}

smote = SMOTE(sampling_strategy=target_classes, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print(y_resampled.value_counts())
# Out:
# AttackType
# BruteForce      50000
# XSS             50000
# SQLInjection    50000
# Name: count, dtype: int64

# %%
scaler = MinMaxScaler()
X_resampled_scaled = scaler.fit_transform(X_resampled)

X_resampled_scaled = pd.DataFrame(X_resampled_scaled, columns=X_resampled.columns)

X_resampled_scaled.describe()
# Out:
#        Fwd IAT Total  Flow IAT Min       Idle Max  Packet Length Variance  \
# count  150000.000000  1.500000e+05  150000.000000           150000.000000
# mean        0.085620  4.804135e-03       0.019385                0.052821
# std         0.173143  5.789747e-02       0.121855                0.109115
# min         0.000000  0.000000e+00       0.000000                0.000000
# 25%         0.000108  2.938390e-07       0.000000                0.000000
# 50%         0.045324  1.583187e-06       0.000000                0.000000
# 75%         0.050047  2.224858e-06       0.000000                0.028380
# max         1.000000  1.000000e+00       1.000000                1.000000
#
#        Bwd Header Length  Flow Duration     Active Max  Fwd Packet Length Max  \
# count      150000.000000  150000.000000  150000.000000          150000.000000
# mean            0.064233       0.092445       0.021604               0.177144
# std             0.176985       0.170714       0.144965               0.246273
# min             0.000000       0.000000       0.000000               0.000000
# 25%             0.010941       0.044451       0.000000               0.000000
# 50%             0.010941       0.045745       0.000000               0.000000
# 75%             0.025164       0.050459       0.000000               0.477269
# max             1.000000       1.000000       1.000000               1.000000
#
#        Fwd Packets/s  Fwd Packet Length Mean  ...   Flow Bytes/s  \
# count  150000.000000           150000.000000  ...  150000.000000
# mean        0.011900                0.098329  ...       0.034021
# std         0.040126                0.161487  ...       0.083469
# min         0.000000                0.000000  ...       0.000000
# 25%         0.000001                0.000000  ...       0.000000
# 50%         0.000002                0.000000  ...       0.000000
# 75%         0.000007                0.185206  ...       0.017877
# max         1.000000                1.000000  ...       1.000000
#
#        Packet Length Std    Bwd IAT Std     Active Min  \
# count      150000.000000  150000.000000  150000.000000
# mean            0.118071       0.164892       0.021604
# std             0.195090       0.346111       0.144965
# min             0.000000       0.000000       0.000000
# 25%             0.000000       0.000000       0.000000
# 50%             0.000000       0.000000       0.000000
# 75%             0.167825       0.001774       0.000000
# max             1.000000       1.000000       1.000000
#
#        Bwd Packet Length Mean  Fwd PSH Flags  Bwd Packet Length Max  \
# count           150000.000000  150000.000000          150000.000000
# mean                 0.120116       0.000007               0.063371
# std                  0.241616       0.002582               0.110845
# min                  0.000000       0.000000               0.000000
# 25%                  0.000000       0.000000               0.000000
# 50%                  0.000000       0.000000               0.000000
# 75%                  0.072961       0.000000               0.065954
# max                  1.000000       1.000000               1.000000
#
#        Subflow Fwd Bytes       Idle Min  Fwd Header Length
# count      150000.000000  150000.000000      150000.000000
# mean            0.080429       0.006031           0.063893
# std             0.256503       0.059849           0.176957
# min             0.000000       0.000000           0.000000
# 25%             0.000000       0.000000           0.013545
# 50%             0.000000       0.000000           0.015312
# 75%             0.010492       0.000000           0.015312
# max             1.000000       1.000000           1.000000
#
# [8 rows x 49 columns]

# %%
label_encoder = LabelEncoder()
y_resampled_encoded = label_encoder.fit_transform(y_resampled)
unique, counts = np.unique(y_resampled_encoded, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {np.int64(0): np.int64(50000), np.int64(1): np.int64(50000), np.int64(2): np.int64(50000)}

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled_scaled, y_resampled_encoded, test_size=0.2, random_state=42)


model = Sequential([
    Dense(128, activation='relu', input_dim=X_train.shape[1]),  # Primera capa oculta con 128 nodos
    Dropout(0.3),  # Dropout para prevenir sobreajuste
    Dense(64, activation='relu'),  # Segunda capa oculta con 64 nodos
    Dropout(0.3),
    Dense(3, activation='softmax')  # Capa de salida para clasificación multiclase (3 clases)
])

# 6. Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',  # Para problemas multiclase
              metrics=['accuracy'])

y_train_one_hot = to_categorical(y_train, num_classes=3)
y_test_one_hot = to_categorical(y_test, num_classes=3)

# Entrenar el modelo
history = model.fit(X_train, y_train_one_hot, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Evaluar el modelo
test_loss, test_accuracy = model.evaluate(X_test, y_test_one_hot)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# Epoch 1/50
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 392us/step - accuracy: 0.6673 - loss: 0.6472 - val_accuracy: 0.7161 - val_loss: 0.5391
# Epoch 2/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 370us/step - accuracy: 0.7225 - loss: 0.5294 - val_accuracy: 0.7576 - val_loss: 0.4785
# Epoch 3/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7512 - loss: 0.4680 - val_accuracy: 0.7527 - val_loss: 0.4381
# Epoch 4/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7564 - loss: 0.4454 - val_accuracy: 0.7608 - val_loss: 0.4268
# Epoch 5/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7619 - loss: 0.4377 - val_accuracy: 0.7808 - val_loss: 0.4157
# Epoch 6/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7651 - loss: 0.4288 - val_accuracy: 0.7742 - val_loss: 0.4144
# Epoch 7/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7691 - loss: 0.4258 - val_accuracy: 0.7617 - val_loss: 0.4163
# Epoch 8/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7700 - loss: 0.4216 - val_accuracy: 0.7811 - val_loss: 0.4035
# Epoch 9/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 384us/step - accuracy: 0.7696 - loss: 0.4200 - val_accuracy: 0.7791 - val_loss: 0.4035
# Epoch 10/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.7720 - loss: 0.4166 - val_accuracy: 0.7935 - val_loss: 0.3997
# Epoch 11/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 381us/step - accuracy: 0.7727 - loss: 0.4139 - val_accuracy: 0.7870 - val_loss: 0.4011
# Epoch 12/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - accuracy: 0.7723 - loss: 0.4146 - val_accuracy: 0.7828 - val_loss: 0.4021
# Epoch 13/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7747 - loss: 0.4109 - val_accuracy: 0.7889 - val_loss: 0.3961
# Epoch 14/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7747 - loss: 0.4103 - val_accuracy: 0.7922 - val_loss: 0.3959
# Epoch 15/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7756 - loss: 0.4080 - val_accuracy: 0.7885 - val_loss: 0.3937
# Epoch 16/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - accuracy: 0.7745 - loss: 0.4109 - val_accuracy: 0.7963 - val_loss: 0.3900
# Epoch 17/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7747 - loss: 0.4097 - val_accuracy: 0.7844 - val_loss: 0.4031
# Epoch 18/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7800 - loss: 0.4071 - val_accuracy: 0.7934 - val_loss: 0.3894
# Epoch 19/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7779 - loss: 0.4047 - val_accuracy: 0.7916 - val_loss: 0.3954
# Epoch 20/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7763 - loss: 0.4042 - val_accuracy: 0.7877 - val_loss: 0.4024
# Epoch 21/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 367us/step - accuracy: 0.7752 - loss: 0.4050 - val_accuracy: 0.7925 - val_loss: 0.3951
# Epoch 22/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - accuracy: 0.7787 - loss: 0.4055 - val_accuracy: 0.7654 - val_loss: 0.3964
# Epoch 23/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - accuracy: 0.7771 - loss: 0.4029 - val_accuracy: 0.7870 - val_loss: 0.3935
# Epoch 24/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7811 - loss: 0.4004 - val_accuracy: 0.7977 - val_loss: 0.3863
# Epoch 25/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7799 - loss: 0.4020 - val_accuracy: 0.7896 - val_loss: 0.3916
# Epoch 26/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7788 - loss: 0.4000 - val_accuracy: 0.7948 - val_loss: 0.3888
# Epoch 27/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7789 - loss: 0.4033 - val_accuracy: 0.7855 - val_loss: 0.4056
# Epoch 28/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 363us/step - accuracy: 0.7809 - loss: 0.3996 - val_accuracy: 0.7881 - val_loss: 0.3882
# Epoch 29/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - accuracy: 0.7793 - loss: 0.4027 - val_accuracy: 0.7910 - val_loss: 0.3937
# Epoch 30/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7818 - loss: 0.3989 - val_accuracy: 0.7900 - val_loss: 0.3876
# Epoch 31/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7822 - loss: 0.3994 - val_accuracy: 0.7901 - val_loss: 0.3873
# Epoch 32/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7819 - loss: 0.3990 - val_accuracy: 0.7961 - val_loss: 0.3848
# Epoch 33/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7844 - loss: 0.3962 - val_accuracy: 0.7720 - val_loss: 0.3916
# Epoch 34/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.7839 - loss: 0.3972 - val_accuracy: 0.7898 - val_loss: 0.3881
# Epoch 35/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7820 - loss: 0.3987 - val_accuracy: 0.7983 - val_loss: 0.3841
# Epoch 36/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7818 - loss: 0.3972 - val_accuracy: 0.7903 - val_loss: 0.3841
# Epoch 37/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7838 - loss: 0.3940 - val_accuracy: 0.7897 - val_loss: 0.3882
# Epoch 38/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 377us/step - accuracy: 0.7844 - loss: 0.3945 - val_accuracy: 0.7813 - val_loss: 0.3844
# Epoch 39/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7835 - loss: 0.3985 - val_accuracy: 0.7943 - val_loss: 0.3815
# Epoch 40/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7825 - loss: 0.3968 - val_accuracy: 0.7971 - val_loss: 0.3826
# Epoch 41/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 366us/step - accuracy: 0.7830 - loss: 0.3975 - val_accuracy: 0.7857 - val_loss: 0.3852
# Epoch 42/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 376us/step - accuracy: 0.7851 - loss: 0.3940 - val_accuracy: 0.7923 - val_loss: 0.3822
# Epoch 43/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7880 - loss: 0.3937 - val_accuracy: 0.7810 - val_loss: 0.3874
# Epoch 44/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7835 - loss: 0.3978 - val_accuracy: 0.7918 - val_loss: 0.3859
# Epoch 45/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7855 - loss: 0.3924 - val_accuracy: 0.7975 - val_loss: 0.3798
# Epoch 46/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - accuracy: 0.7837 - loss: 0.3974 - val_accuracy: 0.7934 - val_loss: 0.3836
# Epoch 47/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 364us/step - accuracy: 0.7845 - loss: 0.3955 - val_accuracy: 0.7974 - val_loss: 0.3824
# Epoch 48/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 365us/step - accuracy: 0.7860 - loss: 0.3933 - val_accuracy: 0.7973 - val_loss: 0.3819
# Epoch 49/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 423us/step - accuracy: 0.7843 - loss: 0.3970 - val_accuracy: 0.7932 - val_loss: 0.3832
# Epoch 50/50
# 3000/3000 ━━━━━━━━━━━━━━━━━━━━ 1s 396us/step - accuracy: 0.7902 - loss: 0.3890 - val_accuracy: 0.7985 - val_loss: 0.3772
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 220us/step - accuracy: 0.8025 - loss: 0.3697
# Test Accuracy: 0.81

# %%
# Predict the labels for the test set
y_pred_nn = model.predict(X_test)
y_pred_nn_classes = np.argmax(y_pred_nn, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_nn_classes)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# Calculate and print other performance metrics
accuracy = accuracy_score(y_test, y_pred_nn_classes)
precision = precision_score(y_test, y_pred_nn_classes, average='weighted')
recall = recall_score(y_test, y_pred_nn_classes, average='weighted')
f1 = f1_score(y_test, y_pred_nn_classes, average='weighted')

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 232us/step
# Accuracy: 0.81
# Precision: 0.81
# Recall: 0.81
# F1 Score: 0.80

# %% [markdown]
# ## New aproach
#
# We tried to use another NN for Level 3 classifing but the performance is not great. As we don't have a lot of data (at least real data) for the Level 3 classes we will try to use a XGBoost model to classify the Level 3 classes. XGBoost is powerful and adds randomness to the model, so it doesn't overfit.

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
# Asegúrate de que tus datos estén preparados correctamente
X_train, X_test, y_train, y_test = train_test_split(X_resampled_scaled, y_resampled_encoded, test_size=0.2, random_state=42)

# Crear el modelo XGBoost
model_xgb = xgb.XGBClassifier(
    n_estimators=100,  # Número de árboles
    max_depth=6,  # Profundidad máxima de los árboles
    learning_rate=0.1,  # Tasa de aprendizaje
    objective='multi:softmax',  # Para clasificación multiclase
    num_class=3,  # Número de clases
    use_label_encoder=False  # Para evitar un warning
)

# Entrenar el modelo
model_xgb.fit(X_train, y_train)

# Hacer predicciones en los datos de prueba
y_pred = model_xgb.predict(X_test)

# Calcular la precisión
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy:.2f}")
print(f"Test Loss: {test_loss:.2f}")
# Out:
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Test Accuracy: 0.86
# Test Loss: 0.37

# %% [markdown]
# #### Fine Tunning XGBoost
#
# We are using `param_grid` to fine tune the model. We will use `GridSearchCV` to find the best parameters for the model. We will use the following parameters:
#
# - `n_estimators`: Number of trees in the forest.
# - `max_depth`: The maximum depth of the tree.
# - `learning_rate`: The learning rate of the model.
# - `subsample`: The fraction of samples to be used for fitting the individual base learners.
# - `colsample_bytree`: The fraction of features to be used for fitting the individual base learners.

# %%
from sklearn.model_selection import GridSearchCV

# Definir el rango de parámetros para el ajuste
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 6, 9],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Crear el modelo XGBoost
model_xgb = xgb.XGBClassifier(objective='multi:softmax', num_class=3, use_label_encoder=False)

# Realizar búsqueda en cuadrícula
grid_search = GridSearchCV(estimator=model_xgb, param_grid=param_grid, cv=3, scoring='accuracy', verbose=1)
grid_search.fit(X_train, y_train)

# Mejor combinación de hiperparámetros
print("Best parameters found: ", grid_search.best_params_)

# Evaluar el modelo con los mejores hiperparámetros
y_pred = grid_search.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy with GridSearchCV: {accuracy:.2f}")
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:07:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:08:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:09:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:55] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:10:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:28] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:11:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nico/Desktop/UPC/PAE/SentinelX/.venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [01:12:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters found:  {'colsample_bytree': 1.0, 'learning_rate': 0.2, 'max_depth': 9, 'n_estimators': 200, 'subsample': 1.0}
# Test Accuracy with GridSearchCV: 0.96

# %%
# Use the best estimator from the grid search to predict the labels for the test set
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test)

# Compute the confusion matrix
cm_best = confusion_matrix(y_test, y_pred_best)

# Plot the confusion matrix
disp_best = ConfusionMatrixDisplay(confusion_matrix=cm_best, display_labels=label_encoder.classes_)
disp_best.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix with Best Parameters')
plt.show()

# Calculate and print other performance metrics
accuracy_best = accuracy_score(y_test, y_pred_best)
precision_best = precision_score(y_test, y_pred_best, average='weighted')
recall_best = recall_score(y_test, y_pred_best, average='weighted')
f1_best = f1_score(y_test, y_pred_best, average='weighted')

print(f'Accuracy: {accuracy_best:.2f}')
print(f'Precision: {precision_best:.2f}')
print(f'Recall: {recall_best:.2f}')
print(f'F1 Score: {f1_best:.2f}')
# Out:
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96

# %% [markdown]
# As we can see, results are much better than any other model we've tried so far. We will use (at the moment) this model to classify the Level 3 classes.

# %%
import joblib

# Save the model to a file
joblib_file = "LayerModels/lvl3_xgboost_model.pkl"
joblib.dump(best_model, joblib_file)

print(f"Model saved to {joblib_file}")
# Out:
# Model saved to LayerModels/lvl3_xgboost_model.pkl
